# %%
# !pip install manim
# Out:
# Collecting manim
#   Using cached manim-0.20.1-py3-none-any.whl.metadata (10 kB)
# Collecting audioop-lts>=0.2.1 (from manim)
#   Using cached audioop_lts-0.2.2-cp313-abi3-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (2.0 kB)
# Collecting av>=15.0 (from manim)
#   Using cached av-17.1.0-cp311-abi3-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: beautifulsoup4>=4.12 in /usr/local/venv/lib/python3.13/site-packages (from manim) (4.15.0)
# Collecting click>=8.0 (from manim)
#   Using cached click-8.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting cloup>=2.0.0 (from manim)
#   Using cached cloup-3.1.0-py2.py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: decorator>=4.3.2 in /usr/local/venv/lib/python3.13/site-packages (from manim) (5.3.1)
# Collecting isosurfaces>=0.1.1 (from manim)
#   Using cached isosurfaces-0.1.2-py3-none-any.whl.metadata (3.3 kB)
# Collecting manimpango<1.0.0,>=0.6.1 (from manim)
#   Using cached manimpango-0.6.1.tar.gz (4.1 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting mapbox-earcut>=1.0.0 (from manim)
#   Downloading mapbox_earcut-2.0.0-cp313-cp313-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.5 kB)
# Collecting moderngl-window>=2.0.0 (from manim)
#   Downloading moderngl_window-3.1.1-py3-none-any.whl.metadata (9.0 kB)
# Collecting moderngl<6.0.0,>=5.7.0 (from manim)
#   Downloading moderngl-5.12.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.8 kB)
# Collecting networkx>=2.6 (from manim)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting numpy>=2.1 (from manim)
#   Downloading numpy-2.5.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting pillow>=11.0 (from manim)
#   Downloading pillow-12.2.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pycairo<2.0.0,>=1.14 (from manim)
#   Downloading pycairo-1.29.0.tar.gz (665 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 665.9/665.9 kB 10.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pydub>=0.22.0 (from manim)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: pygments>=2.17 in /usr/local/venv/lib/python3.13/site-packages (from manim) (2.20.0)
# Collecting rich>=12.0.0 (from manim)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting scipy>=1.13.0 (from manim)
#   Downloading scipy-1.18.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting screeninfo>=0.7.0 (from manim)
#   Downloading screeninfo-0.8.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting skia-pathops>=0.9.0 (from manim)
#   Downloading skia_pathops-0.9.2-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.5 kB)
# Collecting srt>=3.0.0 (from manim)
#   Downloading srt-3.5.3.tar.gz (28 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting svgelements>=1.9.0 (from manim)
#   Downloading svgelements-1.9.6-py2.py3-none-any.whl.metadata (44 kB)
# Collecting tqdm>=4.21.0 (from manim)
#   Downloading tqdm-4.68.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions>=4.12.0 in /usr/local/venv/lib/python3.13/site-packages (from manim) (4.15.0)
# Collecting watchdog>=2.0.0 (from manim)
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
# Collecting glcontext>=3.0.0 (from moderngl<6.0.0,>=5.7.0->manim)
#   Downloading glcontext-3.0.0-cp313-cp313-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.0 kB)
# Requirement already satisfied: soupsieve>=1.6.1 in /usr/local/venv/lib/python3.13/site-packages (from beautifulsoup4>=4.12->manim) (2.8.4)
# Collecting pyglet>=2.0.0 (from moderngl-window>=2.0.0->manim)
#   Downloading pyglet-2.1.14-py3-none-any.whl.metadata (7.7 kB)
# Collecting pyglm<3,>=2.7.0 (from moderngl-window>=2.0.0->manim)
#   Downloading pyglm-2.8.3-cp313-cp313-manylinux_2_34_x86_64.whl.metadata (13 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.0.0->manim)
#   Downloading markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.0.0->manim)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading manim-0.20.1-py3-none-any.whl (652 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 652.1/652.1 kB 13.7 MB/s eta 0:00:00
# Downloading moderngl-5.12.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (296 kB)
# Downloading audioop_lts-0.2.2-cp313-abi3-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (85 kB)
# Downloading av-17.1.0-cp311-abi3-manylinux_2_28_x86_64.whl (35.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.4/35.4 MB 8.2 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Downloading click-8.4.1-py3-none-any.whl (116 kB)
# Downloading cloup-3.1.0-py2.py3-none-any.whl (55 kB)
# Downloading glcontext-3.0.0-cp313-cp313-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (51 kB)
# Downloading isosurfaces-0.1.2-py3-none-any.whl (11 kB)
# Downloading mapbox_earcut-2.0.0-cp313-cp313-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (59 kB)
# Downloading moderngl_window-3.1.1-py3-none-any.whl (382 kB)
# Downloading pyglm-2.8.3-cp313-cp313-manylinux_2_34_x86_64.whl (11.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 7.6 MB/s eta 0:00:007.7 MB/s eta 0:00:01
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 9.4 MB/s eta 0:00:000 MB/s eta 0:00:01
# Downloading numpy-2.5.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 9.8 MB/s eta 0:00:000m eta 0:00:010:01:01
# Downloading pillow-12.2.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 7.2 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading pyglet-2.1.14-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 3.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading scipy-1.18.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 7.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading screeninfo-0.8.1-py3-none-any.whl (12 kB)
# Downloading skia_pathops-0.9.2-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 5.2 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading svgelements-1.9.6-py2.py3-none-any.whl (137 kB)
# Downloading tqdm-4.68.3-py3-none-any.whl (78 kB)
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
# Building wheels for collected packages: manimpango, pycairo, srt
#   Building wheel for manimpango (pyproject.toml) ... done
#   Created wheel for manimpango: filename=manimpango-0.6.1-cp313-cp313-linux_x86_64.whl size=474953 sha256=597938581d1b20368971aca795508d95337f0e5882ba14fc810d6fdbb1a7ea08
#   Stored in directory: /home/fagner/.cache/pip/wheels/f6/75/f3/e6b6413454cb75b6629e139f41a0c9aac3c43037f80c02854b
#   Building wheel for pycairo (pyproject.toml) ... done
#   Created wheel for pycairo: filename=pycairo-1.29.0-cp313-cp313-linux_x86_64.whl size=132285 sha256=8af63a230306ed8196b9b03f9be496d3c78119c7199f896957af06b54d8f6544
#   Stored in directory: /home/fagner/.cache/pip/wheels/b4/d0/8f/2c0daa76a1e7257d9d7005911e351b6eb0fedb77b4e5426ada
#   Building wheel for srt (pyproject.toml) ... done
#   Created wheel for srt: filename=srt-3.5.3-py3-none-any.whl size=22511 sha256=496919218a0d18cd1e7fe75f9c6b54cf77b9469d19019fee3fadf2e0bd150946
#   Stored in directory: /home/fagner/.cache/pip/wheels/ed/9d/54/8e040c593adecbf10de5a6263add15cfefff5a033e33fda8c6
# Successfully built manimpango pycairo srt
# Installing collected packages: svgelements, pyglm, pydub, glcontext, watchdog, tqdm, srt, skia-pathops, screeninfo, pyglet, pycairo, pillow, numpy, networkx, moderngl, mdurl, manimpango, click, av, audioop-lts, scipy, moderngl-window, markdown-it-py, mapbox-earcut, isosurfaces, cloup, rich, manim
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28/28 [manim]38;5;237m━ 27/28 [manim]y]]
# Successfully installed audioop-lts-0.2.2 av-17.1.0 click-8.4.1 cloup-3.1.0 glcontext-3.0.0 isosurfaces-0.1.2 manim-0.20.1 manimpango-0.6.1 mapbox-earcut-2.0.0 markdown-it-py-4.2.0 mdurl-0.1.2 moderngl-5.12.0 moderngl-window-3.1.1 networkx-3.6.1 numpy-2.5.0 pillow-12.2.0 pycairo-1.29.0 pydub-0.25.1 pyglet-2.1.14 pyglm-2.8.3 rich-15.0.0 scipy-1.18.0 screeninfo-0.8.1 skia-pathops-0.9.2 srt-3.5.3 svgelements-1.9.6 tqdm-4.68.3 watchdog-6.0.0

# %%
from manim import *

class Intro(Scene):
    def construct(self):
        p1 = MathTex("Mb_{mj}=\\sum_{k}B_{mk}Ma_{kj}").to_corner(UL)
        p2 = MathTex("\\frac{\\partial Mb_{ij}}{\\partial Ma_{mn}}=B_{im} \\cdot \\delta_{jn}").next_to(p1, DOWN).to_edge(LEFT)
        p3= MathTex("\\frac{\\partial P}{\\partial Ma_{mn}} = \\sum_{i,j} \\frac{\\partial P}{\\partial Mb_{ij}} \\cdot \\frac{\\partial Mb_{ij}}{\\partial Ma_{mn}}").next_to(p2, DOWN).to_edge(LEFT)
        p4= MathTex("\\frac{\\partial P}{\\partial Ma_{mn}} = \\sum_{i,j} \\frac{\\partial P}{\\partial Mb_{ij}} \\cdot B_{im} \\cdot \\delta_{jn}").next_to(p3, DOWN).to_edge(LEFT)
        
        p5= MathTex("\\frac{\\partial P}{\\partial Ma_{mn}} = \\sum_{i} \\frac{\\partial P}{\\partial Mb_{in}} \\cdot B_{im}").next_to(p4, RIGHT).to_edge(UP)
        p6=MathTex("\\frac{\\partial P}{\\partial Ma_{mn}}=(B^T)_{mi}\\cdot \\frac{\\partial P}{\\partial Mb_{in}}").next_to(p5, DOWN)
        p7=MathTex("\\frac{\\partial P}{\\partial Ma}=B^T\\cdot \\frac{\\partial P}{\\partial Mb}").next_to(p6, DOWN)

        g2 =VGroup(p1,p2,p3,p4,p5,p6,p7)
        
        self.play(Write(g2))
        self.wait(1)
# %manim -qm Intro
# Out:
# Manim Community v0.20.1
# [06/23/26 18:40:04] INFO     Animation 0 : Using cached data (hash :                           ]8;id=13093785;file:///usr/local/venv/lib/python3.13/site-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=13093786;file:///usr/local/venv/lib/python3.13/site-packages/manim/renderer/cairo_renderer.py#94\94]8;;\
#                              1987512680_692522440_223132457)
# [06/23/26 18:40:05] INFO     Animation 1 : Using cached data (hash :                           ]8;id=13093791;file:///usr/local/venv/lib/python3.13/site-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=13093792;file:///usr/local/venv/lib/python3.13/site-packages/manim/renderer/cairo_renderer.py#94\94]8;;\
#                              2538612922_1839128356_3194585033)
#                     INFO     Combining to Movie file.                                      ]8;id=13093797;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=13093798;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#753\753]8;;\
#                     INFO                                                                   ]8;id=13093803;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=13093804;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#904\904]8;;\
#                              File ready at
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/Intro.mp4'
#                     INFO     Rendered Intro                                                            ]8;id=13093809;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=13093810;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene.py#278\278]8;;\
#                              Played 2 animations
# <video src="media/jupyter/Intro@2026-06-23@18-40-05.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from manim import *

class Intro(Scene):
    def construct(self):
        p1 = MathTex("Ma_{mj}=\\sum_{k}X_{mk}A_{kj}").to_corner(UL)
        p2 = MathTex("\\frac{\\partial Ma_{ij}}{\\partial X_{mn}}= \\delta_{im} \\cdot A_{nj}").next_to(p1, DOWN).to_edge(LEFT)
        p3= MathTex("\\frac{\\partial Mb}{\\partial X_{mn}} = \\sum_{i,j} \\frac{\\partial Mb}{\\partial Ma_{ij}} \\cdot \\frac{\\partial Ma_{ij}}{\\partial X_{mn}}").next_to(p2, DOWN).to_edge(LEFT)
        p4= MathTex("\\frac{\\partial Mb}{\\partial X_{mn}} = \\sum_{i,j} \\frac{\\partial Mb}{\\partial Ma_{ij}} \\cdot \\delta_{im} \\cdot A_{nj}").next_to(p3, DOWN).to_edge(LEFT)
        
        p5= MathTex("\\frac{\\partial Mb}{\\partial X_{mn}} = \\sum_{j} \\frac{\\partial Mb}{\\partial Ma_{mj}} \\cdot A_{nj}").next_to(p4, RIGHT).to_edge(UP)
        p6=MathTex("\\frac{\\partial Mb}{\\partial X_{mn}}= \\sum_{j} \\frac{\\partial Mb}{\\partial Ma_{mj}} \\cdot (A^T)_{jn}").next_to(p5, DOWN)
        p7=MathTex("\\frac{\\partial Mb}{\\partial X}=\\frac{\\partial Mb}{\\partial X} \\cdot A^T").next_to(p6, DOWN)

        g2 =VGroup(p1,p2,p3,p4,p5,p6,p7)
        
        self.play(Write(g2))
        self.wait(1)
# %manim -qm Intro
# Out:
# Manim Community v0.20.1
# [06/23/26 17:45:11] INFO     Animation 0 : Partial movie file written in                   ]8;id=13093645;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=13093646;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/Intro/1987512
#                              680_1867255984_223132457.mp4'
# [06/23/26 17:45:12] INFO     Animation 1 : Partial movie file written in                   ]8;id=13093651;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=13093652;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/Intro/2538612
#                              922_1839128356_3158688053.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=13093657;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=13093658;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#753\753]8;;\
#                     INFO                                                                   ]8;id=13093663;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=13093664;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#904\904]8;;\
#                              File ready at
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/Intro.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=13093669;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=13093670;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#874\874]8;;\
#                              manim has removed the 2 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Intro                                                            ]8;id=13093675;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=13093676;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene.py#278\278]8;;\
#                              Played 2 animations
# <video src="media/jupyter/Intro@2026-06-23@17-45-12.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from manim import *

class Intro(Scene):
    def construct(self):
        e = MathTex("e=A_l-P_l").to_corner(UR)
        p = MathTex("P_l=\\sum_{X_{l-1,i}}^{N_{l-1,i}}Mb \\cdot W_{l,i}").next_to(e, DOWN).to_edge(LEFT)
        b = MathTex("Mb=B \\times Ma").next_to(p, DOWN).to_edge(LEFT)
        a = MathTex("Ma=X_{l-1,i} \\times A").next_to(b, DOWN).to_edge(LEFT)
        g1 = VGroup(e,p,b,a)

        self.play(Write(g1))
        self.wait(1)
# %manim -qm Intro
# Out:
# Manim Community v0.20.1
# [06/23/26 17:45:26] INFO     Animation 0 : Partial movie file written in                   ]8;id=13093681;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=13093682;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/Intro/1987512
#                              680_67533577_223132457.mp4'
# [06/23/26 17:45:27] INFO     Animation 1 : Partial movie file written in                   ]8;id=13093687;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=13093688;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/Intro/2538612
#                              922_1839128356_1564434215.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=13093693;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=13093694;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#753\753]8;;\
#                     INFO                                                                   ]8;id=13093699;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=13093700;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#904\904]8;;\
#                              File ready at
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/Intro.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=13093705;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=13093706;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#874\874]8;;\
#                              manim has removed the 2 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Intro                                                            ]8;id=13093711;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=13093712;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene.py#278\278]8;;\
#                              Played 2 animations
# <video src="media/jupyter/Intro@2026-06-23@17-45-27.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from manim import *
import numpy as np

class SigmoidSmoothLines(Scene):
    def construct(self):
        axes = Axes(
            x_range=[-3, 8, 1],  
            y_range=[-2, 2, 1],
            x_length=12,
            y_length=6,
            axis_config={
                "include_tip": True,
                "numbers_to_include": range(-3, 4),
            },
            tips=False,
        )
        axes_labels = axes.get_axis_labels(x_label="x", y_label="f(x)")
        w11=ValueTracker(2)
        w12=ValueTracker(-3)
        w21=ValueTracker(2)
        w22=ValueTracker(-7)
        wo1=1
        wo2=-1

        def sigmoid(x):
            return 1/(1+np.exp(-x))
        def h1():
            return axes.plot(lambda x: sigmoid(x*w11.get_value()+w12.get_value()), color=BLUE)
        
        def h2():
            return axes.plot(lambda x: sigmoid(x*w21.get_value()+w22.get_value()), color=GREEN)

        def pf(x):
            a = sigmoid(x*w11.get_value()+w12.get_value())
            b = sigmoid(x*w21.get_value()+w22.get_value())
            return wo1*a+wo2*b
        def p():
            return axes.plot(lambda x: pf(x), color=ORANGE)

        def labelsf():
            p3 = MathTex("p=w_1^o\\cdot \\sigma(h_1) + w_2^o\\cdot \\sigma(h_2)").to_corner(DR)
            p2 = MathTex("h_2=w_2\\cdot x+b_2").next_to(p3, UP).to_edge(RIGHT)
            p1 = MathTex("h_1=w_1\\cdot x+b_1").next_to(p2, UP).to_edge(RIGHT)
                                                        
            p4 = MathTex(f"w_1={w11.get_value():.2f},b_1={w12.get_value():.2f}").to_corner(UR)
            p5 = MathTex(f"w_2={w21.get_value():.2f},b_2={w22.get_value():.2f}").next_to(p4, DOWN).to_edge(RIGHT)
            p6 = MathTex(f"w^o_1={wo1:.2f},w^o_2={wo2:.2f}").next_to(p5, DOWN).to_edge(RIGHT)
            return VGroup(p1, p2, p3,p4,p5,p6)
        labels = always_redraw(labelsf)
        graphh1= always_redraw(h1)
        graphh2= always_redraw(h2)
        graphp= always_redraw(p)
        
        # Animate them
        self.add(axes, axes_labels)
        self.play(Create(graphh1), Create(graphh2), Create(graphp))
        self.play(Create(labels))
        self.play(w12.animate.set_value(2),run_time=4)
        self.play(w12.animate.set_value(-14),run_time=4)
        self.play(w12.animate.set_value(-3),run_time=4)

        self.play(w22.animate.set_value(2),run_time=4)
        self.play(w22.animate.set_value(-17),run_time=4)
        self.play(w22.animate.set_value(-7),run_time=4)

        self.play(w11.animate.set_value(-6), run_time=5)
        self.play(w11.animate.set_value(6), run_time=5)
        self.play(w11.animate.set_value(2))

        self.play(w21.animate.set_value(-6), run_time=5)
        self.play(w21.animate.set_value(6), run_time=5)
        self.play(w21.animate.set_value(2))
        
        self.wait(10)

# %manim -qm SigmoidSmoothLines
# Out:
# Manim Community v0.20.1
# [06/29/26 12:42:12] INFO     Animation 0 : Partial movie file written in                   ]8;id=15241805;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=15241806;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/SigmoidSmooth
#                              Lines/1987512680_3933176779_609633633.mp4'
# [06/29/26 12:42:18] INFO     Animation 1 : Partial movie file written in                   ]8;id=15241811;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=15241812;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/SigmoidSmooth
#                              Lines/2538612922_2880187095_433412608.mp4'
# Animation 2: _MethodAnimation(ValueTracker):   4%|██▌                                                          | 5/120 [00:00<00:18,  6.33it/s]
# [06/29/26 12:42:20] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241817;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241818;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.98\special{dvisvgm:raw </g>}
#                              to media/Tex/1e13e739658212ca.tex
# Animation 2: _MethodAnimation(ValueTracker):   8%|████▌                                                        | 9/120 [00:02<00:30,  3.62it/s]
# [06/29/26 12:42:22] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241823;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241824;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.96\special{dvisvgm:raw </g>}
#                              to media/Tex/97f06aed2cb9dc9f.tex
# Animation 2: _MethodAnimation(ValueTracker):   9%|█████▌                                                      | 11/120 [00:03<00:41,  2.60it/s]
# [06/29/26 12:42:23] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241829;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241830;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.95\special{dvisvgm:raw </g>}
#                              to media/Tex/e42e989889647fa3.tex
# Animation 2: _MethodAnimation(ValueTracker):  12%|███████                                                     | 14/120 [00:04<00:38,  2.77it/s]
# [06/29/26 12:42:24] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241835;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241836;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.93\special{dvisvgm:raw </g>}
#                              to media/Tex/99b32a0d808ed7ed.tex
# Animation 2: _MethodAnimation(ValueTracker):  12%|███████▌                                                    | 15/120 [00:05<00:54,  1.93it/s]
# [06/29/26 12:42:25] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241841;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241842;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.92\special{dvisvgm:raw </g>}
#                              to media/Tex/51a1fb3e874f0db9.tex
# Animation 2: _MethodAnimation(ValueTracker):  14%|████████▌                                                   | 17/120 [00:06<00:50,  2.04it/s]
# [06/29/26 12:42:26] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241847;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241848;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.90\special{dvisvgm:raw </g>}
#                              to media/Tex/42d2685c6812a19b.tex
# Animation 2: _MethodAnimation(ValueTracker):  15%|█████████                                                   | 18/120 [00:07<01:03,  1.61it/s]
# [06/29/26 12:42:27] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241853;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241854;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.89\special{dvisvgm:raw </g>}
#                              to media/Tex/69e941de4a1b455c.tex
# Animation 2: _MethodAnimation(ValueTracker):  16%|█████████▌                                                  | 19/120 [00:08<01:15,  1.35it/s]
# [06/29/26 12:42:28] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241859;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241860;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.87\special{dvisvgm:raw </g>}
#                              to media/Tex/2669c9f94a87d393.tex
# Animation 2: _MethodAnimation(ValueTracker):  18%|██████████▌                                                 | 21/120 [00:10<01:04,  1.54it/s]
# [06/29/26 12:42:29] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241865;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241866;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.84\special{dvisvgm:raw </g>}
#                              to media/Tex/233cffd46f5b9277.tex
# Animation 2: _MethodAnimation(ValueTracker):  18%|███████████                                                 | 22/120 [00:11<01:10,  1.39it/s]
# [06/29/26 12:42:30] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241871;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241872;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.83\special{dvisvgm:raw </g>}
#                              to media/Tex/9d32ec2a794211ba.tex
# Animation 2: _MethodAnimation(ValueTracker):  19%|███████████▌                                                | 23/120 [00:11<01:15,  1.28it/s]
# [06/29/26 12:42:31] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241877;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241878;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.81\special{dvisvgm:raw </g>}
#                              to media/Tex/2a424414c53f59cc.tex
# Animation 2: _MethodAnimation(ValueTracker):  21%|████████████▌                                               | 25/120 [00:13<01:00,  1.57it/s]
# [06/29/26 12:42:32] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241883;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241884;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.77\special{dvisvgm:raw </g>}
#                              to media/Tex/30c8cfc456cad437.tex
# Animation 2: _MethodAnimation(ValueTracker):  22%|█████████████                                               | 26/120 [00:13<01:07,  1.40it/s]
# [06/29/26 12:42:33] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241889;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241890;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.75\special{dvisvgm:raw </g>}
#                              to media/Tex/f4838e80eb87e327.tex
# Animation 2: _MethodAnimation(ValueTracker):  22%|█████████████▌                                              | 27/120 [00:14<01:10,  1.31it/s]
# [06/29/26 12:42:34] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241895;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241896;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.73\special{dvisvgm:raw </g>}
#                              to media/Tex/01967c5d3bffd319.tex
# Animation 2: _MethodAnimation(ValueTracker):  24%|██████████████▌                                             | 29/120 [00:15<00:53,  1.70it/s]
# [06/29/26 12:42:35] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241901;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241902;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.68\special{dvisvgm:raw </g>}
#                              to media/Tex/e16cd7eda428f69e.tex
# Animation 2: _MethodAnimation(ValueTracker):  25%|███████████████                                             | 30/120 [00:16<01:00,  1.50it/s]
# [06/29/26 12:42:36] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241907;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241908;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.65\special{dvisvgm:raw </g>}
#                              to media/Tex/b20661a3aa8deecf.tex
# Animation 2: _MethodAnimation(ValueTracker):  26%|███████████████▌                                            | 31/120 [00:17<01:05,  1.36it/s]
# [06/29/26 12:42:37] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241913;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241914;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.62\special{dvisvgm:raw </g>}
#                              to media/Tex/38bbe1a1017af188.tex
# Animation 2: _MethodAnimation(ValueTracker):  28%|████████████████▌                                           | 33/120 [00:18<00:51,  1.71it/s]
# [06/29/26 12:42:38] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241919;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241920;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.55\special{dvisvgm:raw </g>}
#                              to media/Tex/dae590212b4df8c2.tex
# Animation 2: _MethodAnimation(ValueTracker):  28%|█████████████████                                           | 34/120 [00:19<00:57,  1.48it/s]
# [06/29/26 12:42:39] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241925;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241926;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.51\special{dvisvgm:raw </g>}
#                              to media/Tex/99dd3ab86995cb75.tex
# Animation 2: _MethodAnimation(ValueTracker):  29%|█████████████████▌                                          | 35/120 [00:20<01:02,  1.37it/s]
#                     INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241931;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241932;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.47\special{dvisvgm:raw </g>}
#                              to media/Tex/ed48024c45f4ddab.tex
# Animation 2: _MethodAnimation(ValueTracker):  31%|██████████████████▌                                         | 37/120 [00:21<00:50,  1.63it/s]
# [06/29/26 12:42:41] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241937;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241938;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.38\special{dvisvgm:raw </g>}
#                              to media/Tex/2562de47882d8221.tex
# Animation 2: _MethodAnimation(ValueTracker):  32%|███████████████████                                         | 38/120 [00:22<00:58,  1.41it/s]
#                     INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241943;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241944;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.34\special{dvisvgm:raw </g>}
#                              to media/Tex/ea60bee8bea56620.tex
# Animation 2: _MethodAnimation(ValueTracker):  32%|███████████████████▌                                        | 39/120 [00:23<01:04,  1.25it/s]
# [06/29/26 12:42:42] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241949;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241950;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.28\special{dvisvgm:raw </g>}
#                              to media/Tex/a2f53af88ccfdc1c.tex
# Animation 2: _MethodAnimation(ValueTracker):  34%|████████████████████▌                                       | 41/120 [00:24<00:51,  1.55it/s]
# [06/29/26 12:42:44] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241955;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241956;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.17\special{dvisvgm:raw </g>}
#                              to media/Tex/3991913fd0ea46c9.tex
# Animation 2: _MethodAnimation(ValueTracker):  35%|█████████████████████                                       | 42/120 [00:25<01:00,  1.30it/s]
# [06/29/26 12:42:45] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241961;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241962;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.11\special{dvisvgm:raw </g>}
#                              to media/Tex/3fb4d969dce57985.tex
# Animation 2: _MethodAnimation(ValueTracker):  36%|█████████████████████▌                                      | 43/120 [00:26<01:05,  1.18it/s]
# [06/29/26 12:42:46] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241967;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241968;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-2.04\special{dvisvgm:raw </g>}
#                              to media/Tex/5de27cfae9fb6d34.tex
# Animation 2: _MethodAnimation(ValueTracker):  38%|██████████████████████▌                                     | 45/120 [00:27<00:47,  1.56it/s]
# [06/29/26 12:42:47] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241973;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241974;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-1.91\special{dvisvgm:raw </g>}
#                              to media/Tex/dafc634b3bdb76e6.tex
# Animation 2: _MethodAnimation(ValueTracker):  38%|███████████████████████                                     | 46/120 [00:28<00:52,  1.42it/s]
# [06/29/26 12:42:48] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241979;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241980;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-1.83\special{dvisvgm:raw </g>}
#                              to media/Tex/f5c47f2a5570d6d4.tex
# Animation 2: _MethodAnimation(ValueTracker):  39%|███████████████████████▌                                    | 47/120 [00:29<00:58,  1.24it/s]
# [06/29/26 12:42:49] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241985;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241986;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-1.75\special{dvisvgm:raw </g>}
#                              to media/Tex/6633069f214ebd10.tex
# Animation 2: _MethodAnimation(ValueTracker):  41%|████████████████████████▌                                   | 49/120 [00:30<00:45,  1.55it/s]
# [06/29/26 12:42:50] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241991;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241992;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-1.59\special{dvisvgm:raw </g>}
#                              to media/Tex/e88b024070874d85.tex
# Animation 2: _MethodAnimation(ValueTracker):  42%|█████████████████████████                                   | 50/120 [00:31<00:53,  1.31it/s]
# [06/29/26 12:42:51] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15241997;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15241998;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-1.50\special{dvisvgm:raw </g>}
#                              to media/Tex/1be40675865534e3.tex
# Animation 2: _MethodAnimation(ValueTracker):  42%|█████████████████████████▌                                  | 51/120 [00:32<00:59,  1.15it/s]
# [06/29/26 12:42:52] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242003;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242004;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-1.41\special{dvisvgm:raw </g>}
#                              to media/Tex/1a8e6e224ccdc320.tex
# Animation 2: _MethodAnimation(ValueTracker):  44%|██████████████████████████▌                                 | 53/120 [00:33<00:44,  1.51it/s]
# [06/29/26 12:42:53] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242009;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242010;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-1.22\special{dvisvgm:raw </g>}
#                              to media/Tex/509cf9c523119293.tex
# Animation 2: _MethodAnimation(ValueTracker):  45%|███████████████████████████                                 | 54/120 [00:34<00:49,  1.33it/s]
# [06/29/26 12:42:54] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242015;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242016;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-1.12\special{dvisvgm:raw </g>}
#                              to media/Tex/a67ef4c063566766.tex
# Animation 2: _MethodAnimation(ValueTracker):  46%|███████████████████████████▌                                | 55/120 [00:35<00:51,  1.26it/s]
# [06/29/26 12:42:55] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242021;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242022;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-1.02\special{dvisvgm:raw </g>}
#                              to media/Tex/e8135aa3723256ba.tex
# Animation 2: _MethodAnimation(ValueTracker):  48%|████████████████████████████▌                               | 57/120 [00:36<00:40,  1.55it/s]
# [06/29/26 12:42:56] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242027;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242028;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-0.82\special{dvisvgm:raw </g>}
#                              to media/Tex/000b08366b0ce6a5.tex
# Animation 2: _MethodAnimation(ValueTracker):  48%|█████████████████████████████                               | 58/120 [00:37<00:45,  1.37it/s]
# [06/29/26 12:42:57] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242033;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242034;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-0.71\special{dvisvgm:raw </g>}
#                              to media/Tex/ebda1f7fa9b08645.tex
# Animation 2: _MethodAnimation(ValueTracker):  49%|█████████████████████████████▌                              | 59/120 [00:38<00:47,  1.29it/s]
# [06/29/26 12:42:58] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242039;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242040;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-0.61\special{dvisvgm:raw </g>}
#                              to media/Tex/df196fe930b12a5c.tex
# Animation 2: _MethodAnimation(ValueTracker):  51%|██████████████████████████████▌                             | 61/120 [00:39<00:36,  1.60it/s]
# [06/29/26 12:42:59] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242045;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242046;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-0.39\special{dvisvgm:raw </g>}
#                              to media/Tex/561681341132a123.tex
# Animation 2: _MethodAnimation(ValueTracker):  52%|███████████████████████████████                             | 62/120 [00:40<00:41,  1.39it/s]
# [06/29/26 12:43:00] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242051;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242052;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-0.29\special{dvisvgm:raw </g>}
#                              to media/Tex/4e2631e6cd560e2b.tex
# Animation 2: _MethodAnimation(ValueTracker):  52%|███████████████████████████████▌                            | 63/120 [00:41<00:43,  1.30it/s]
# [06/29/26 12:43:01] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242057;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242058;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=-0.18\special{dvisvgm:raw </g>}
#                              to media/Tex/8ab77075e6e24005.tex
# Animation 2: _MethodAnimation(ValueTracker):  54%|████████████████████████████████▌                           | 65/120 [00:42<00:33,  1.65it/s]
# [06/29/26 12:43:02] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242063;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242064;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=0.02\special{dvisvgm:raw </g>} to
#                              media/Tex/fb6cc0c17f303731.tex
# Animation 2: _MethodAnimation(ValueTracker):  55%|█████████████████████████████████                           | 66/120 [00:43<00:38,  1.41it/s]
# [06/29/26 12:43:03] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242069;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242070;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=0.12\special{dvisvgm:raw </g>} to
#                              media/Tex/e1662306de8e9901.tex
# Animation 2: _MethodAnimation(ValueTracker):  56%|█████████████████████████████████▌                          | 67/120 [00:44<00:42,  1.26it/s]
# [06/29/26 12:43:04] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242075;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242076;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=0.22\special{dvisvgm:raw </g>} to
#                              media/Tex/2618630a4c8f25cd.tex
# Animation 2: _MethodAnimation(ValueTracker):  57%|██████████████████████████████████▌                         | 69/120 [00:45<00:32,  1.59it/s]
# [06/29/26 12:43:05] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242081;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242082;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=0.41\special{dvisvgm:raw </g>} to
#                              media/Tex/9013aa6a6add7791.tex
# Animation 2: _MethodAnimation(ValueTracker):  58%|███████████████████████████████████                         | 70/120 [00:46<00:38,  1.30it/s]
# [06/29/26 12:43:06] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242087;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242088;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=0.50\special{dvisvgm:raw </g>} to
#                              media/Tex/e945f82b1b87aea7.tex
# Animation 2: _MethodAnimation(ValueTracker):  59%|███████████████████████████████████▌                        | 71/120 [00:47<00:40,  1.22it/s]
# [06/29/26 12:43:07] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242093;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242094;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=0.59\special{dvisvgm:raw </g>} to
#                              media/Tex/071075f5bf773803.tex
# Animation 2: _MethodAnimation(ValueTracker):  61%|████████████████████████████████████▌                       | 73/120 [00:48<00:31,  1.50it/s]
# [06/29/26 12:43:08] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242099;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242100;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=0.75\special{dvisvgm:raw </g>} to
#                              media/Tex/6cb3970f9102b6b9.tex
# Animation 2: _MethodAnimation(ValueTracker):  62%|█████████████████████████████████████                       | 74/120 [00:49<00:33,  1.37it/s]
# [06/29/26 12:43:09] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242105;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242106;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=0.83\special{dvisvgm:raw </g>} to
#                              media/Tex/4cc845a465be5bdf.tex
# Animation 2: _MethodAnimation(ValueTracker):  62%|█████████████████████████████████████▌                      | 75/120 [00:50<00:34,  1.30it/s]
# [06/29/26 12:43:10] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242111;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242112;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=0.91\special{dvisvgm:raw </g>} to
#                              media/Tex/7037d4d6ad7ef739.tex
# Animation 2: _MethodAnimation(ValueTracker):  64%|██████████████████████████████████████▌                     | 77/120 [00:51<00:26,  1.64it/s]
# [06/29/26 12:43:11] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242117;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242118;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=1.04\special{dvisvgm:raw </g>} to
#                              media/Tex/b9bf821b925c8b2f.tex
# Animation 2: _MethodAnimation(ValueTracker):  65%|███████████████████████████████████████                     | 78/120 [00:52<00:30,  1.39it/s]
# [06/29/26 12:43:12] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242123;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242124;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=1.11\special{dvisvgm:raw </g>} to
#                              media/Tex/628a4598f7c10641.tex
# Animation 2: _MethodAnimation(ValueTracker):  66%|███████████████████████████████████████▌                    | 79/120 [00:53<00:32,  1.25it/s]
# [06/29/26 12:43:13] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242129;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242130;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=1.17\special{dvisvgm:raw </g>} to
#                              media/Tex/3aa13a5d5e501182.tex
# Animation 2: _MethodAnimation(ValueTracker):  68%|████████████████████████████████████████▌                   | 81/120 [00:54<00:25,  1.50it/s]
# [06/29/26 12:43:14] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242135;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242136;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=1.28\special{dvisvgm:raw </g>} to
#                              media/Tex/83d51edb8e308666.tex
# Animation 2: _MethodAnimation(ValueTracker):  69%|█████████████████████████████████████████▌                  | 83/120 [00:55<00:20,  1.78it/s]
# [06/29/26 12:43:15] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242141;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242142;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=1.38\special{dvisvgm:raw </g>} to
#                              media/Tex/1b8ce560b13b8d45.tex
# Animation 2: _MethodAnimation(ValueTracker):  71%|██████████████████████████████████████████▌                 | 85/120 [00:57<00:18,  1.90it/s]
# [06/29/26 12:43:16] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242147;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242148;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=1.47\special{dvisvgm:raw </g>} to
#                              media/Tex/e82a2ec17280819f.tex
# Animation 2: _MethodAnimation(ValueTracker):  72%|███████████████████████████████████████████                 | 86/120 [00:58<00:23,  1.46it/s]
# [06/29/26 12:43:17] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242153;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242154;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=1.51\special{dvisvgm:raw </g>} to
#                              media/Tex/f3bded71ffaa37eb.tex
# Animation 2: _MethodAnimation(ValueTracker):  74%|████████████████████████████████████████████▌               | 89/120 [00:59<00:14,  2.13it/s]
# [06/29/26 12:43:19] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242159;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242160;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=1.62\special{dvisvgm:raw </g>} to
#                              media/Tex/6b491cc9d7dac1a3.tex
# Animation 2: _MethodAnimation(ValueTracker):  75%|█████████████████████████████████████████████               | 90/120 [01:00<00:18,  1.62it/s]
#                     INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242165;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242166;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=1.65\special{dvisvgm:raw </g>} to
#                              media/Tex/b5e6376d5b022cba.tex
# Animation 2: _MethodAnimation(ValueTracker):  76%|█████████████████████████████████████████████▌              | 91/120 [01:01<00:20,  1.41it/s]
# [06/29/26 12:43:20] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242171;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242172;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=1.68\special{dvisvgm:raw </g>} to
#                              media/Tex/e82ec8a6be4542fe.tex
# Animation 2: _MethodAnimation(ValueTracker):  78%|██████████████████████████████████████████████▌             | 93/120 [01:02<00:16,  1.63it/s]
# [06/29/26 12:43:22] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242177;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242178;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=1.73\special{dvisvgm:raw </g>} to
#                              media/Tex/bbac58c52599e487.tex
# Animation 2: _MethodAnimation(ValueTracker):  78%|███████████████████████████████████████████████             | 94/120 [01:03<00:18,  1.41it/s]
# [06/29/26 12:43:23] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242183;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242184;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=1.75\special{dvisvgm:raw </g>} to
#                              media/Tex/0a3e797a91b23a78.tex
# Animation 2: _MethodAnimation(ValueTracker):  79%|███████████████████████████████████████████████▌            | 95/120 [01:04<00:19,  1.27it/s]
#                     INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242189;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242190;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=1.77\special{dvisvgm:raw </g>} to
#                              media/Tex/2176e820cb50caf3.tex
# Animation 2: _MethodAnimation(ValueTracker):  81%|████████████████████████████████████████████████▌           | 97/120 [01:05<00:14,  1.54it/s]
# [06/29/26 12:43:25] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242195;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242196;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=1.81\special{dvisvgm:raw </g>} to
#                              media/Tex/8454169eebf7a602.tex
# Animation 2: _MethodAnimation(ValueTracker):  82%|█████████████████████████████████████████████████           | 98/120 [01:06<00:16,  1.34it/s]
# [06/29/26 12:43:26] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242201;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242202;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=1.83\special{dvisvgm:raw </g>} to
#                              media/Tex/f4a4ee403e2c7638.tex
# Animation 2: _MethodAnimation(ValueTracker):  82%|█████████████████████████████████████████████████▌          | 99/120 [01:07<00:17,  1.23it/s]
# [06/29/26 12:43:27] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242207;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242208;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=1.84\special{dvisvgm:raw </g>} to
#                              media/Tex/4a4fba3042b9e4fd.tex
# Animation 2: _MethodAnimation(ValueTracker):  84%|█████████████████████████████████████████████████▋         | 101/120 [01:08<00:12,  1.47it/s]
# [06/29/26 12:43:28] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242213;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242214;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=1.87\special{dvisvgm:raw </g>} to
#                              media/Tex/a78f6a9b9a0ba7c1.tex
# Animation 2: _MethodAnimation(ValueTracker):  85%|██████████████████████████████████████████████████▏        | 102/120 [01:09<00:13,  1.34it/s]
# [06/29/26 12:43:29] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242219;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242220;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=1.89\special{dvisvgm:raw </g>} to
#                              media/Tex/be211bfe7dade2cf.tex
# Animation 2: _MethodAnimation(ValueTracker):  88%|███████████████████████████████████████████████████▋       | 105/120 [01:11<00:07,  1.91it/s]
# [06/29/26 12:43:30] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242225;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242226;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=1.92\special{dvisvgm:raw </g>} to
#                              media/Tex/7bb711b657af06bd.tex
# Animation 2: _MethodAnimation(ValueTracker):  88%|████████████████████████████████████████████████████       | 106/120 [01:12<00:09,  1.45it/s]
# [06/29/26 12:43:31] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242231;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242232;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=1.93\special{dvisvgm:raw </g>} to
#                              media/Tex/0a15fd36215ab19f.tex
# Animation 2: _MethodAnimation(ValueTracker):  91%|█████████████████████████████████████████████████████▌     | 109/120 [01:13<00:05,  1.97it/s]
# [06/29/26 12:43:33] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242237;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242238;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_1=2.00,b_1=1.95\special{dvisvgm:raw </g>} to
#                              media/Tex/99c391d345b9d011.tex
# Animation 2: _MethodAnimation(ValueTracker):  95%|████████████████████████████████████████████████████████   | 114/120 [01:15<00:01,  3.04it/s]
# [06/29/26 12:43:35] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15242243;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15242244;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
# ...
#                              id='unique000'>}w_2=2.00,b_2=-7.38\special{dvisvgm:raw </g>}
#                              to media/Tex/1f38bbea6f0fe447.tex
# Animation 7: _MethodAnimation(ValueTracker):  82%|█████████████████████████████████████████████████           | 98/120 [01:04<00:14,  1.49it/s]
# [06/29/26 12:50:40] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15244451;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15244452;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_2=2.00,b_2=-7.34\special{dvisvgm:raw </g>}
#                              to media/Tex/809bdecd43e549fd.tex
# Animation 7: _MethodAnimation(ValueTracker):  82%|█████████████████████████████████████████████████▌          | 99/120 [01:05<00:15,  1.34it/s]
# [06/29/26 12:50:41] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15244457;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15244458;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_2=2.00,b_2=-7.31\special{dvisvgm:raw </g>}
#                              to media/Tex/7fb03061ad9a1bbe.tex
# Animation 7: _MethodAnimation(ValueTracker):  84%|█████████████████████████████████████████████████▋         | 101/120 [01:06<00:11,  1.64it/s]
# [06/29/26 12:50:42] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15244463;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15244464;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_2=2.00,b_2=-7.25\special{dvisvgm:raw </g>}
#                              to media/Tex/e7605396679af742.tex
# Animation 7: _MethodAnimation(ValueTracker):  85%|██████████████████████████████████████████████████▏        | 102/120 [01:07<00:12,  1.41it/s]
# [06/29/26 12:50:43] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15244469;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15244470;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_2=2.00,b_2=-7.23\special{dvisvgm:raw </g>}
#                              to media/Tex/6f3ae4a1341ad2e5.tex
# Animation 7: _MethodAnimation(ValueTracker):  86%|██████████████████████████████████████████████████▋        | 103/120 [01:08<00:13,  1.30it/s]
# [06/29/26 12:50:44] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15244475;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15244476;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_2=2.00,b_2=-7.21\special{dvisvgm:raw </g>}
#                              to media/Tex/983d669b20bd38cf.tex
# Animation 7: _MethodAnimation(ValueTracker):  88%|███████████████████████████████████████████████████▋       | 105/120 [01:09<00:09,  1.58it/s]
# [06/29/26 12:50:45] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15244481;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15244482;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_2=2.00,b_2=-7.17\special{dvisvgm:raw </g>}
#                              to media/Tex/da9101b65644d1be.tex
# Animation 7: _MethodAnimation(ValueTracker):  88%|████████████████████████████████████████████████████       | 106/120 [01:11<00:10,  1.28it/s]
# [06/29/26 12:50:46] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15244487;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15244488;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_2=2.00,b_2=-7.15\special{dvisvgm:raw </g>}
#                              to media/Tex/026823ff62ba18dd.tex
# Animation 7: _MethodAnimation(ValueTracker):  89%|████████████████████████████████████████████████████▌      | 107/120 [01:11<00:10,  1.21it/s]
# [06/29/26 12:50:47] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15244493;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15244494;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_2=2.00,b_2=-7.13\special{dvisvgm:raw </g>}
#                              to media/Tex/414e9fae1ac2fe9c.tex
# Animation 7: _MethodAnimation(ValueTracker):  92%|██████████████████████████████████████████████████████     | 110/120 [01:13<00:05,  1.97it/s]
# [06/29/26 12:50:48] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15244499;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15244500;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_2=2.00,b_2=-7.09\special{dvisvgm:raw </g>}
#                              to media/Tex/ea16fcf0b592e8df.tex
# Animation 7: _MethodAnimation(ValueTracker):  92%|██████████████████████████████████████████████████████▌    | 111/120 [01:14<00:05,  1.58it/s]
# [06/29/26 12:50:49] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15244505;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15244506;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_2=2.00,b_2=-7.07\special{dvisvgm:raw </g>}
#                              to media/Tex/5a7cf907034fdfc6.tex
# Animation 7: _MethodAnimation(ValueTracker):  94%|███████████████████████████████████████████████████████▌   | 113/120 [01:15<00:03,  1.79it/s]
# [06/29/26 12:50:50] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15244511;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15244512;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_2=2.00,b_2=-7.05\special{dvisvgm:raw </g>}
#                              to media/Tex/226aabb51b1fd2f8.tex
# Animation 7: _MethodAnimation(ValueTracker):  95%|████████████████████████████████████████████████████████   | 114/120 [01:16<00:03,  1.51it/s]
# [06/29/26 12:50:51] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15244517;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15244518;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_2=2.00,b_2=-7.04\special{dvisvgm:raw </g>}
#                              to media/Tex/537a484181a60afd.tex
# Animation 7: _MethodAnimation(ValueTracker):  98%|█████████████████████████████████████████████████████████▌ | 117/120 [01:17<00:01,  2.22it/s]
# [06/29/26 12:50:52] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15244523;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15244524;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_2=2.00,b_2=-7.02\special{dvisvgm:raw </g>}
#                              to media/Tex/bace85a0a36be620.tex
# Animation 7: _MethodAnimation(ValueTracker):  98%|██████████████████████████████████████████████████████████ | 118/120 [01:18<00:01,  1.70it/s]
# [06/29/26 12:50:53] INFO     Writing \special{dvisvgm:raw <g                                ]8;id=15244529;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=15244530;file:///usr/local/venv/lib/python3.13/site-packages/manim/utils/tex_file_writing.py#110\110]8;;\
#                              id='unique000'>}w_2=2.00,b_2=-7.01\special{dvisvgm:raw </g>}
#                              to media/Tex/287589e8bb022339.tex
# [06/29/26 12:50:54] INFO     Animation 7 : Partial movie file written in                   ]8;id=15244535;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=15244536;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/SigmoidSmooth
#                              Lines/2538612922_198381714_1134924763.mp4'
# [06/29/26 12:51:24] INFO     Animation 8 : Partial movie file written in                   ]8;id=15244541;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=15244542;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/SigmoidSmooth
#                              Lines/2538612922_2031725907_418247517.mp4'
# [06/29/26 12:51:58] INFO     Animation 9 : Partial movie file written in                   ]8;id=15244547;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=15244548;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/SigmoidSmooth
#                              Lines/2538612922_1714472328_620221563.mp4'
# [06/29/26 12:52:05] INFO     Animation 10 : Partial movie file written in                  ]8;id=15244553;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=15244554;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/SigmoidSmooth
#                              Lines/2538612922_2999668414_1037832922.mp4'
# [06/29/26 12:52:40] INFO     Animation 11 : Partial movie file written in                  ]8;id=15244559;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=15244560;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/SigmoidSmooth
#                              Lines/2538612922_2031725907_2455993922.mp4'
# [06/29/26 12:53:13] INFO     Animation 12 : Partial movie file written in                  ]8;id=15244565;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=15244566;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/SigmoidSmooth
#                              Lines/2538612922_1714472328_976288165.mp4'
# [06/29/26 12:53:19] INFO     Animation 13 : Partial movie file written in                  ]8;id=15244571;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=15244572;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/SigmoidSmooth
#                              Lines/2538612922_2999668414_2273187713.mp4'
# [06/29/26 12:53:23] INFO     Animation 14 : Partial movie file written in                  ]8;id=15244577;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=15244578;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/SigmoidSmooth
#                              Lines/2538612922_105223348_4011840997.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=15244583;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=15244584;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#753\753]8;;\
#                     INFO                                                                   ]8;id=15244589;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=15244590;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#904\904]8;;\
#                              File ready at
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/SigmoidSmoothLines.mp4'
#                     INFO     Rendered SigmoidSmoothLines                                               ]8;id=15244595;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=15244596;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene.py#278\278]8;;\
#                              Played 15 animations
# <video src="media/jupyter/SigmoidSmoothLines@2026-06-29@12-53-23.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from manim import *

class Derivative2(Scene):
    def construct(self):
        axes = Axes(
            x_range=[-3, 3, 1],  
            y_range=[-3, 3, 1],
            x_length=6,
            y_length=6,
            axis_config={
                "include_tip": True,
                "numbers_to_include": range(-3, 4),
            },
            tips=False,
        )

        axes_labels = axes.get_axis_labels(x_label="x", y_label="f(x)")
        
        def f(x,a=0, w=1, y=0):
            return ((a-(x*w+y))**2)/2

        def d(x,a=0,w=1,y=0):
            return -w*(a-(x*w+y))
        
        # Plot the function
        graph = axes.plot(lambda x: f(x), color=BLUE, x_range=[-3, 3])
        derivative = axes.plot(lambda x: d(x), color=GREEN, x_range=[-3, 3])
        ggraph = axes.plot(lambda x: -d(x), color=PINK, x_range=[-3,3])

        tracker = ValueTracker(-2)
        def tang():
            x0 = tracker.get_value()
            y0 = f(x0)
            x1 = x0+0.001
            y1 = f(x1)
            slope = (y1-y0)/(x1-x0)
            point = axes.c2p(x0, y0)
            point2= axes.c2p(x1, y1)
            return VGroup(axes.plot( lambda x: slope * (x - x0) + y0,
                                color=RED,
                                x_range=[x0 - 1.5, x0 + 1.5]), Dot(point=point))
            
        
        
        # Derivative (slope) at x0: f'(x) = 2x, so f'(1) = 2
        
        # Tangent line: y = slope * (x - x0) + y0
        # We plot it across a small range around x0 for visibility
        tangent = always_redraw(   tang        )

        
        
        # Optional: add a label on the curve
        graph_label = axes.get_graph_label(
            graph, 
            label="(x_{lj}-\\sum_{x_{(l-1)k}}^{N_{(l-1)}}x_{(l-1)k}*w_{(l-1)k})^2", 
            x_val=2, 
            direction=UP
        )
        
        # Animate them
        self.play(Create(axes))
        self.play(Create(graph),Create(ggraph),Create(derivative))
        self.play(Write(graph_label))
        self.play(Create(tangent))
        self.play(tracker.animate.set_value(2), run_time=4)
        self.play(tracker.animate.set_value(-2), run_time=4)
        self.wait(5)

# %manim -qm Derivative2
# Out:
# Manim Community v0.20.1
# [06/23/26 17:45:32] INFO     Animation 0 : Partial movie file written in                   ]8;id=13093717;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=13093718;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/Derivative2/1
#                              987512680_1003784273_223132457.mp4'
#                     INFO     Animation 1 : Partial movie file written in                   ]8;id=13093723;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=13093724;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/Derivative2/2
#                              538612922_2173164099_2017914475.mp4'
# [06/23/26 17:45:34] INFO     Animation 2 : Partial movie file written in                   ]8;id=13093729;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=13093730;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/Derivative2/2
#                              538612922_3787609706_553377209.mp4'
# [06/23/26 17:45:35] INFO     Animation 3 : Partial movie file written in                   ]8;id=13093735;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=13093736;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/Derivative2/2
#                              538612922_3359402725_2500392100.mp4'
# [06/23/26 17:45:37] INFO     Animation 4 : Partial movie file written in                   ]8;id=13093741;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=13093742;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/Derivative2/2
#                              538612922_1498395877_1166512474.mp4'
# [06/23/26 17:45:39] INFO     Animation 5 : Partial movie file written in                   ]8;id=13093747;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=13093748;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/Derivative2/2
#                              538612922_2749523760_3317752085.mp4'
# [06/23/26 17:45:40] INFO     Animation 6 : Partial movie file written in                   ]8;id=13093753;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=13093754;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/Derivative2/2
#                              538612922_2015106682_2663549624.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=13093759;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=13093760;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#753\753]8;;\
#                     INFO                                                                   ]8;id=13093765;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=13093766;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#904\904]8;;\
#                              File ready at
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/Derivative2.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=13093771;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=13093772;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#874\874]8;;\
#                              manim has removed the 7 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Derivative2                                                      ]8;id=13093777;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=13093778;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene.py#278\278]8;;\
#                              Played 7 animations
# <video src="media/jupyter/Derivative2@2026-06-23@17-45-41.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from manim import *
import numpy as np

class NetworkOutput(ThreeDScene):
    def construct(self):
        axes = ThreeDAxes(
            x_range=[-1, 1, 1],  
            y_range=[-1, 1, 1],
            z_range=[-1, 1, 1],
            x_length=4,
            y_length=4,
            z_length=4,
            tips=False,
        )
        x_label = axes.get_x_axis_label("X")
        y_label = axes.get_y_axis_label("Y")
        z_label = axes.get_z_axis_label("Z")

        def sigmoid(x):
            return 1/(1+np.exp(-x))
        w11=-3.81343
        w12=-3.58818
        w13=0.753555
        w21=-0.932131
        w22=-0.773737
        w23=-0.171377
        wo1=-8.68617
        wo2=11.6513
        wo3=-1.40196
        surface = Surface(
            lambda u, v: np.array([u,v, sigmoid(u*wo1+v*wo2+wo3)]),
            u_range=[-1, 1],
            v_range=[-1, 1],
            resolution=(32, 32), # Keep this relatively low (e.g., 32) or rendering will take forever
            checkerboard_colors=[BLUE_D, BLUE_E],
            fill_opacity=0.8
        )
        self.set_camera_orientation(phi=70 * DEGREES, theta=-45 * DEGREES)
        
        
        # Animate them
        self.add(axes, x_label, y_label, z_label)
        self.play(Create(surface))
        self.begin_ambient_camera_rotation(rate=0.15)
        self.wait(10)

# %manim -qm NetworkOutput
# Out:
# Manim Community v0.20.1
# [06/27/26 20:09:07] INFO     Animation 0 : Partial movie file written in                   ]8;id=7808645;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=7808646;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/Derivative2/3
#                              265148996_1464520948_2180175911.mp4'
# [06/27/26 20:11:24] INFO     Animation 1 : Partial movie file written in                   ]8;id=7808651;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=7808652;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/Derivative2/3
#                              313100980_1321280361_227148350.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=7808657;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=7808658;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#753\753]8;;\
#                     INFO                                                                   ]8;id=7808663;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=7808664;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#904\904]8;;\
#                              File ready at
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/Derivative2.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=7808669;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=7808670;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#874\874]8;;\
#                              manim has removed the 2 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Derivative2                                                      ]8;id=7808675;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=7808676;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene.py#278\278]8;;\
#                              Played 2 animations
# <video src="media/jupyter/Derivative2@2026-06-27@20-11-24.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
import matplotlib.pyplot as plt
import numpy as np
# Out:
# [06/29/26 13:21:33] INFO     Failed to extract font properties from                            ]8;id=15244603;file:///usr/local/venv/lib/python3.13/site-packages/matplotlib/font_manager.py\font_manager.py]8;;\:]8;id=15244604;file:///usr/local/venv/lib/python3.13/site-packages/matplotlib/font_manager.py#1263\1263]8;;\
#                              /usr/share/fonts/truetype/noto/NotoColorEmoji.ttf: Non-scalable
#                              fonts are not supported
# [06/29/26 13:21:34] INFO     Failed to extract font properties from                            ]8;id=15244609;file:///usr/local/venv/lib/python3.13/site-packages/matplotlib/font_manager.py\font_manager.py]8;;\:]8;id=15244610;file:///usr/local/venv/lib/python3.13/site-packages/matplotlib/font_manager.py#1263\1263]8;;\
#                              /home/fagner/.local/share/fonts/host-fonts/truetype/noto/NotoColo
#                              rEmoji.ttf: Non-scalable fonts are not supported
#                     INFO     generated new fontManager                                         ]8;id=15244616;file:///usr/local/venv/lib/python3.13/site-packages/matplotlib/font_manager.py\font_manager.py]8;;\:]8;id=15244617;file:///usr/local/venv/lib/python3.13/site-packages/matplotlib/font_manager.py#1847\1847]8;;\

# %%
from manim import *
import colorsys as csys
import numpy as np

class Fourier(Scene):
    def construct(self):
        axes = Axes(
            x_range=[-3, 8, PI*0.25],  
            y_range=[-1, 1, 0.5],
            y_length=2,
            tips=False
        ).to_edge(UP+LEFT)

        axesc = Axes(
            x_range=[-1,1,1],
            y_range=[-1,1,1],
            x_length=4,
            y_length=4,
            tips=False
        ).next_to(axes, DOWN).to_edge(LEFT)

        def f(x):
            return np.sin(x*2)
        c1 = np.array([*csys.hls_to_rgb(h=0.8,s=0.7,l=0.6,),1])
        c2 = np.array([*csys.hls_to_rgb(h=0.1,s=0.8,l=0.6,),1])
        graph = axes.plot(lambda x: f(x), color=c1)
        def circlef(x):
            return np.array([np.cos(x),np.sin(x)])*0.5

        speedTracker = ValueTracker(1)
        def curvef(x):
            h = f(x)
            speed=speedTracker.get_value()
            a = np.sin(x*speed)*h
            b = np.cos(x*speed)*h
            return np.array([a,b])
        
        circle = axesc.plot_parametric_curve(
            circlef,
            t_range=[0,2*PI,0.1],
            color=GRAY
        )
        def curve2(): 
            return axesc.plot_parametric_curve(
                curvef,
                t_range=[0, 2*PI, 0.1],
                color=c2
            )
        curve = always_redraw(curve2)
        freqarr=np.array([[0,0]])
        def frequencyf():
            nonlocal freqarr
            def v(x):
                speed=speedTracker.get_value()
                return np.sin(x*speed)*f(x)
            def h(x):
                speed=speedTracker.get_value()
                return np.cos(x*speed)*f(x)
            x = np.linspace(0, 2*PI)
            a = np.vectorize(h)(x)
            b = np.vectorize(v)(x)
            
            freqarr = np.append(freqarr, [[a.mean()*a.mean()*2,b.mean()]], axis=0)
            x = freqarr[:,0]
            y = freqarr[:,1]
            size = freqarr.shape[0]
            return VGroup(
                axes.plot_line_graph(x_values=np.linspace(0, 6, size),y_values=x,add_vertex_dots=False),
                Dot(point=axesc.c2p(b.mean(), a.mean()))
            )
        
        frequency = always_redraw(frequencyf)
        # Animate them
        self.add(axes, axesc)
        self.play(Create(graph),Create(circle))
        self.play(Create(curve), Create(frequency))
        
        self.play(speedTracker.animate.set_value(0), run_time=3)
        self.play(speedTracker.animate.set_value(6.28), run_time=15)
        self.wait(10)

# %manim -qm Fourier
# Out:
# Manim Community v0.20.1
# [06/29/26 16:06:09] INFO     Animation 0 : Using cached data (hash :                           ]8;id=15247698;file:///usr/local/venv/lib/python3.13/site-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=15247699;file:///usr/local/venv/lib/python3.13/site-packages/manim/renderer/cairo_renderer.py#94\94]8;;\
#                              1987512680_866135573_1161692406)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=15247704;file:///usr/local/venv/lib/python3.13/site-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=15247705;file:///usr/local/venv/lib/python3.13/site-packages/manim/renderer/cairo_renderer.py#94\94]8;;\
#                              2538612922_1907424412_1980734510)
# [06/29/26 16:06:11] INFO     Animation 2 : Partial movie file written in                   ]8;id=15247710;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=15247711;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/Fourier/25386
#                              12922_478812784_1856758116.mp4'
# [06/29/26 16:06:29] INFO     Animation 3 : Partial movie file written in                   ]8;id=15247716;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=15247717;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/Fourier/25386
#                              12922_1806210746_1351792674.mp4'
# [06/29/26 16:06:32] INFO     Animation 4 : Partial movie file written in                   ]8;id=15247722;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=15247723;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#601\601]8;;\
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/partial_movie_files/Fourier/25386
#                              12922_2678054126_3171975610.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=15247728;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=15247729;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#753\753]8;;\
#                     INFO                                                                   ]8;id=15247734;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=15247735;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#904\904]8;;\
#                              File ready at
#                              '/home/fagner/Documents/Projects/predictive-coding/media/vide
#                              os/predictive-coding/720p30/Fourier.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=15247740;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=15247741;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#874\874]8;;\
#                              manim has removed the 3 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Fourier                                                          ]8;id=15247746;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=15247747;file:///usr/local/venv/lib/python3.13/site-packages/manim/scene/scene.py#278\278]8;;\
#                              Played 5 animations
# <video src="media/jupyter/Fourier@2026-06-29@16-06-32.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>
